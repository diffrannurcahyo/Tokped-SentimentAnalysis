# %% [markdown]
# PROSES 1- SCRAPPING

# %%
#menginstall google scraper
# !pip install google-play-scraper

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
 #scrape desire number of reviews
 from google_play_scraper import Sort, reviews

 result, continuation_token = reviews(
    'com.tokopedia.tkpd',
    lang= 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 10000,
    filter_score_with = None
 )

 #scraping tokopedia

# %%
#membuat data frame dengan nama 'datacoba'
df = pd.DataFrame(np.array(result),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))

#menampilkan data teratas
df
# Out:
#                                   reviewId             userName  \
# 0     97fd9567-813d-4cc4-88cb-80055d42de75          Dede NATHAN
# 1     799bf812-a9e8-43f7-963e-16c7382194f1            Ibnu Abas
# 2     f05bd820-4cee-429d-a17f-501b0ea8a543            Natali 25
# 3     d3de4d5b-c76b-49d6-b31a-5c37176c3c73  NoviyaNti0089 Yanti
# 4     4d491cf3-f609-404d-aaef-ee964d1ce7cc       enggineer muda
# ...                                    ...                  ...
# 9995  c47d0310-c493-4d51-8c95-22ad06d98b23       Dewi Fitriyana
# 9996  0a352ce2-c332-4a37-901c-0ec202b48cce       Erni Setyowati
# 9997  17653632-d54c-4264-ad42-5b21ace23c31        Budi Wisedewa
# 9998  518c486a-add3-4420-ac49-9419f001a9cd          niwre helas
# 9999  5b9aea47-fded-4432-be2d-e9adaa1fbfb2       Athalla Farand
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AD5-W...
# 1     https://play-lh.googleusercontent.com/a/AEdFTp...
# ...

# %%
#memastikan jumlah data
len(df.index)
# Out:
# 10000

# %%
#untuk menampilkan nama, skor, tanggal, dan review
df[['userName','score','at','content']].head()
# Out:
#               userName  score                  at  \
# 0          Dede NATHAN      5 2023-01-26 04:29:43
# 1            Ibnu Abas      1 2023-01-26 03:53:35
# 2            Natali 25      5 2023-01-26 03:38:47
# 3  NoviyaNti0089 Yanti      5 2023-01-26 03:10:31
# 4       enggineer muda      4 2023-01-26 02:35:43
#
#                                              content
# 0        Salah satu Marketplace Terbaik di INDONESIA
# 1  Kurir rekomendasinya super lambat, kalau kurir...
# 2  mantaf diskonnya semoga semakin berjaya tokopedia
# 3                                                 Ik
# 4                                                 Ok

# %%
#mengurutkan data berdasarkan tanggal
df_scrape = df[['userName','score','at','content']] 
df_sorted = df_scrape.sort_values(by='at', ascending=False) 
df_sorted.head()
# Out:
#               userName  score                  at  \
# 0          Dede NATHAN      5 2023-01-26 04:29:43
# 1            Ibnu Abas      1 2023-01-26 03:53:35
# 2            Natali 25      5 2023-01-26 03:38:47
# 3  NoviyaNti0089 Yanti      5 2023-01-26 03:10:31
# 4       enggineer muda      4 2023-01-26 02:35:43
#
#                                              content
# 0        Salah satu Marketplace Terbaik di INDONESIA
# 1  Kurir rekomendasinya super lambat, kalau kurir...
# 2  mantaf diskonnya semoga semakin berjaya tokopedia
# 3                                                 Ik
# 4                                                 Ok

# %%
#menghapus variabel lain
df_scrape = df[['userName','score','at','content']]
df_scrape
# Out:
#                  userName  score                  at  \
# 0             Dede NATHAN      5 2023-01-26 04:29:43
# 1               Ibnu Abas      1 2023-01-26 03:53:35
# 2               Natali 25      5 2023-01-26 03:38:47
# 3     NoviyaNti0089 Yanti      5 2023-01-26 03:10:31
# 4          enggineer muda      4 2023-01-26 02:35:43
# ...                   ...    ...                 ...
# 9995       Dewi Fitriyana      5 2022-11-25 18:58:13
# 9996       Erni Setyowati      5 2022-11-25 18:55:18
# 9997        Budi Wisedewa      5 2022-11-25 18:51:59
# 9998          niwre helas      5 2022-11-25 18:50:56
# 9999       Athalla Farand      1 2022-11-25 18:48:13
#
#                                                 content
# 0           Salah satu Marketplace Terbaik di INDONESIA
# 1     Kurir rekomendasinya super lambat, kalau kurir...
# 2     mantaf diskonnya semoga semakin berjaya tokopedia
# 3                                                    Ik
# ...

# %%
df_scrape['score'].value_counts()
# Out:
# 5    5152
# 1    3182
# 4     652
# 2     515
# 3     499
# Name: score, dtype: int64

# %%
#menyimpan data
df_scrape.to_csv("Data_Scrape.csv", index = False)
